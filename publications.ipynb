# %% [markdown]
# # Publications
#
# Also on [Google
# Scholar](https://scholar.google.fr/citations?user=g5MloHAAAAAJ&hl).
# Author names in **bold** are mine.
#
# ## 2026
#
# Charles Moslonka, Amaury de Vitry, Arthur Garnier, **Hicham
# Randrianarivo**, Emmanuel Malherbe. *LEDGER: A Long-Context Benchmark of
# Corporate Annual Reports for Grounded Financial Retrieval and
# Extraction.* CIKM 2026, Resource Track.
# \[[arXiv](https://arxiv.org/abs/2606.13100)\]
# \[[code](https://github.com/artefactory/LEDGER)\]
#
# Charles Moslonka, **Hicham Randrianarivo**, Arthur Garnier, Emmanuel
# Malherbe. *Learned Hallucination Detection in Black-Box LLMs using
# Token-level Entropy Production Rate.* ECIR 2026.
# \[[arXiv](https://arxiv.org/abs/2509.04492)\]
# \[[code](https://github.com/artefactory/artefactual)\]
#
# ## 2021
#
# Chen Dang, **Hicham Randrianarivo**, Raphaël Fournier-S’Niehotta,
# Nicolas Audebert. *Web Image Context Extraction with Graph Neural
# Networks and Sentence Embeddings on the DOM tree.* ECML-PKDD 3rd
# Workshop on Graph Embedding and Mining (GEM), 2021.
# \[[arXiv](https://arxiv.org/abs/2108.11629)\]
#
# ## 2020
#
# Maxime Portaz, Adrien Nivaggioli, **Hicham Randrianarivo**, Ilyes
# Kacher, Sylvain Peyronnet. *QISS: An Open Source Image Similarity Search
# Engine.* Advances in Information Retrieval (ECIR), Springer, 2020,
# p. 486.
#
# Ilyes Kacher, Maxime Portaz, **Hicham Randrianarivo**, Sylvain
# Peyronnet. *Graphcore C2 Card performance for image-based deep learning
# application: A Report.* arXiv preprint, 2020.
# \[[arXiv](https://arxiv.org/abs/2002.11670)\]
#
# ## 2019
#
# Adrien Nivaggioli, **Hicham Randrianarivo**. *Weakly supervised semantic
# segmentation of satellite images.* Joint Urban Remote Sensing Event
# (JURSE), IEEE, 2019, pp. 1–4.
# \[[arXiv](https://arxiv.org/abs/1904.03983)\]
#
# Maxime Portaz, **Hicham Randrianarivo**, Adrien Nivaggioli, Estelle
# Maudet, Christophe Servan, Sylvain Peyronnet. *Image search using
# multilingual texts: a cross-modal learning approach between image and
# text.* arXiv preprint, 2019.
# \[[arXiv](https://arxiv.org/abs/1903.11299)\]
#
# Bertrand Le Saux, **Hicham Randrianarivo**, Nicolas Audebert.
# *Christchurch Aerial Semantic Dataset.* Dataset, December 2019.
# \[[DOI](https://doi.org/10.5281/zenodo.3566005)\]
#
# ## 2017
#
# Nicolas Audebert, Alexandre Boulch, **Hicham Randrianarivo**, Bertrand
# Le Saux, Marin Ferecatu, Sébastien Lefèvre, Renaud Marlet. *Deep
# learning for urban remote sensing.* Joint Urban Remote Sensing Event
# (JURSE), IEEE, 2017, pp. 1–4.
#
# ## 2016
#
# **Hicham Randrianarivo**. *Apprentissage statistique de classes
# sémantiques pour l’interprétation d’images aériennes.* PhD thesis,
# Conservatoire national des arts et métiers (CNAM), 2016.
#
# Manuel Campos-Taberner, Adriana Romero-Soriano, Carlo Gatta, Gustau
# Camps-Valls, Adrien Lagrange, Bertrand Le Saux, Anne Beaupère, Alexandre
# Boulch, Adrien Chan-Hon-Tong, Stéphane Herbin, **Hicham Randrianarivo**,
# et al. *Processing of extremely high-resolution Lidar and RGB data:
# outcome of the 2015 IEEE GRSS data fusion contest – part A: 2-D
# contest.* IEEE Journal of Selected Topics in Applied Earth Observations
# and Remote Sensing, 9(12), 2016, pp. 5547–5559.
#
# **Hicham Randrianarivo**, Bertrand Le Saux, Nicolas Audebert, Michel
# Crucianu, Marin Ferecatu. *Structural classifiers for contextual
# semantic labeling of aerial images.* 2016.
#
# ## 2015
#
# Adrien Lagrange, Bertrand Le Saux, Anne Beaupère, Alexandre Boulch,
# Adrien Chan-Hon-Tong, Stéphane Herbin, **Hicham Randrianarivo**, Marin
# Ferecatu. *Benchmarking classification of earth-observation data: From
# learning explicit features to convolutional networks.* IEEE
# International Geoscience and Remote Sensing Symposium (IGARSS), 2015,
# pp. 4173–4176.
#
# **Hicham Randrianarivo**, Bertrand Le Saux, Michel Crucianu, Marin
# Ferecatu. *Discriminatively-trained model mixture for object detection
# in aerial images.* Image Information Mining, Bucharest, Romania, 2015.
#
# ## 2014
#
# **Hicham Randrianarivo**, Bertrand Le Saux, Marin Ferecatu. *Multimodal
# classification with deformable part-based models for urban cartography.*
# IEEE Geoscience and Remote Sensing Symposium (IGARSS), 2014,
# pp. 203–206.
#
# ## 2013
#
# Bertrand Le Saux, **Hicham Randrianarivo**. *Urban change detection in
# SAR images by interactive learning.* IEEE International Geoscience and
# Remote Sensing Symposium (IGARSS), 2013, pp. 3990–3993.
#
# **Hicham Randrianarivo**, Bertrand Le Saux, Marin Ferecatu. *Urban
# structure detection with deformable part-based models.* IEEE
# International Geoscience and Remote Sensing Symposium (IGARSS), 2013,
# pp. 200–203.
